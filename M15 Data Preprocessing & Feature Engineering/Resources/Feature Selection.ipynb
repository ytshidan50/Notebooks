# %% [markdown]
# 1) FILTER METHOD

# %% [markdown]
# A) CORRELATION

# %%
import pandas as pd

df=pd.read_csv('datascience.csv')

df.select_dtypes(include=['number']).columns
# Out:
# Index(['enrollee_id', 'city_development_index', 'experience', 'training_hours',
#        'target'],
#       dtype='str')

# %%
#Finding correlation between numerical variables.
corr_matrix=df.corr(numeric_only=True).round(2)

# %%
corr_matrix
# Out:
#                         enrollee_id  city_development_index  experience  \
# enrollee_id                    1.00                   -0.04       -0.04
# city_development_index        -0.04                    1.00        0.33
# experience                    -0.04                    0.33        1.00
# training_hours                 0.00                   -0.00       -0.00
# target                         0.05                   -0.34       -0.18
#
#                         training_hours  target
# enrollee_id                       0.00    0.05
# city_development_index           -0.00   -0.34
# experience                       -0.00   -0.18
# training_hours                    1.00   -0.02
# target                           -0.02    1.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.show()

# %%
corr_matrix['target'].sort_values(ascending=False)
# Out:
# target                    1.00
# enrollee_id               0.05
# training_hours           -0.02
# experience               -0.18
# city_development_index   -0.34
# Name: target, dtype: float64

# %%
df=df.drop('enrollee_id',axis=1)

# %%
df.head()
# Out:
#        city  city_development_index gender      relevent_experience  \
# 0  city_103                   0.920   Male  Has relevent experience
# 1   city_40                   0.776   Male   No relevent experience
# 2   city_21                   0.624    NaN   No relevent experience
# 3  city_115                   0.789    NaN   No relevent experience
# 4  city_162                   0.767   Male  Has relevent experience
#
#   enrolled_university education_level major_discipline  experience  \
# 0       no_enrollment        Graduate             STEM        20.0
# 1       no_enrollment        Graduate             STEM        15.0
# 2    Full time course        Graduate             STEM         5.0
# 3                 NaN        Graduate  Business Degree         0.0
# 4       no_enrollment         Masters             STEM        20.0
#
#   company_size    company_type  training_hours  target
# 0          NaN             NaN            36.0     1.0
# ...

# %% [markdown]
# B) VARIANCE THRESHOLD1

# %%
import pandas as pd

df_var = pd.DataFrame({
    'A':[1,1,1,1,1],
    'B':[1,2,3,4,5],
    'C':[10,10,11,10,10],
    'D':[7,7,7,7,7]
})

df_var
# Out:
#    A  B   C  D
# 0  1  1  10  7
# 1  1  2  10  7
# 2  1  3  11  7
# 3  1  4  10  7
# 4  1  5  10  7

# %%
df_var.var()
# Out:
# A    0.0
# B    2.5
# C    0.2
# D    0.0
# dtype: float64

# %%
from sklearn.feature_selection import VarianceThreshold
vt=VarianceThreshold(threshold=0.5)
new_data=vt.fit_transform(df_var)

# %%
vt.get_support()
# Out:
# array([False,  True, False, False])

# %%
import pandas as pd

df=pd.read_csv('datascience.csv')

num_df=df.select_dtypes(include=['number'])

# %%
num_df.var().round(2)
# Out:
# enrollee_id               92473083.22
# city_development_index           0.02
# experience                      42.32
# training_hours                3586.29
# target                           0.19
# dtype: float64

# %%
num_df['target'].unique()
# Out:
# array([1., 0.])

# %%
num_df['city_development_index'].unique()
# Out:
# array([0.92 , 0.776, 0.624, 0.789, 0.767, 0.764, 0.762, 0.913, 0.926,
#        0.827, 0.843, 0.804,   nan, 0.855, 0.887, 0.91 , 0.884, 0.924,
#        0.666, 0.558, 0.923, 0.794, 0.754, 0.939, 0.55 , 0.865, 0.698,
#        0.893, 0.796, 0.866, 0.682, 0.802, 0.579, 0.878, 0.897, 0.949,
#        0.925, 0.896, 0.836, 0.693, 0.769, 0.775, 0.903, 0.555, 0.727,
#        0.64 , 0.516, 0.743, 0.899, 0.915, 0.689, 0.895, 0.89 , 0.847,
#        0.527, 0.766, 0.738, 0.647, 0.795, 0.74 , 0.701, 0.493, 0.84 ,
#        0.691, 0.735, 0.742, 0.479, 0.722, 0.921, 0.848, 0.856, 0.898,
#        0.83 , 0.73 , 0.68 , 0.725, 0.556, 0.448, 0.763, 0.745, 0.645,
#        0.788, 0.78 , 0.512, 0.739, 0.563, 0.518, 0.824, 0.487, 0.649,
#        0.781, 0.625, 0.807, 0.664])

# %%
num_df['experience'].unique()
# Out:
# array([20., 15.,  5.,  0., 11., 13.,  7., 17.,  2., 16.,  1.,  4., 10.,
#        14., 18., 19., 12.,  3.,  6.,  9.,  8., nan])

# %%
num_df['training_hours'].unique()
# Out:
# array([ 36.,  47.,  83.,  52.,   8.,  24.,  18.,  46., 123.,  32., 108.,
#         23.,  26., 106.,   7., 132.,  68.,  50.,  48.,  65.,  13.,  22.,
#        148.,  72.,  40., 141.,  82., 145.,  nan, 152.,  42.,  14., 112.,
#         87.,  20.,  21.,  92., 102.,  43.,  19.,  90.,  25.,  15.,  98.,
#         28., 228.,  29.,  17.,  35.,   4.,  12., 136.,  27.,  74.,  86.,
#         75., 332., 140., 182., 172.,  33., 142.,  34., 150., 160.,   3.,
#          2., 210., 101.,  59., 260., 131.,  45., 109.,  51.,  60., 164.,
#        290.,  70., 133.,  76., 156., 120., 100.,  39.,  55.,  49.,   6.,
#        125., 326., 198.,  11.,  41., 114., 246.,  81.,  31.,  84., 105.,
#         38., 178., 104., 202.,  88., 218.,  62.,  10.,  80.,  37., 162.,
#        190.,  30.,  16.,   5.,  54.,  44., 110., 262., 107., 134., 103.,
#         96.,  57., 240.,  94., 113.,  56.,  64., 320.,   9., 129.,  58.,
#        126., 166.,  95.,  97., 206., 204., 116., 161., 146., 302.,  53.,
# ...

# %%
num_df['city_development_index'].nunique()
# Out:
# 93

# %%
num_df['city_development_index'].describe()
# Out:
# count    18679.000000
# mean         0.828951
# std          0.123334
# min          0.448000
# 25%          0.740000
# 50%          0.903000
# 75%          0.920000
# max          0.949000
# Name: city_development_index, dtype: float64

# %%
num_df['city_development_index'].value_counts()
# Out:
# city_development_index
# 0.920    5078
# 0.624    2619
# 0.910    1502
# 0.926    1297
# 0.698     664
#          ...
# 0.649       4
# 0.807       4
# 0.781       3
# 0.625       3
# 0.664       1
# Name: count, Length: 93, dtype: int64

# %%
import matplotlib.pyplot as plt

num_df.hist(figsize=(12,8), bins=20)

plt.tight_layout()

plt.show()

# %%
df=df.drop('enrollee_id',axis=1)

# %%
import pandas as pd

df=pd.read_csv('adult.csv')

df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  str
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  str
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  str
#  6   occupation      32561 non-null  str
#  7   relationship    32561 non-null  str
#  8   race            32561 non-null  str
#  9   sex             32561 non-null  str
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  str
#  14  income          32561 non-null  str
# dtypes: int64(6), str(9)
# memory usage: 3.7 MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education.num        16
# marital.status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital.gain        119
# capital.loss         92
# hours.per.week       94
# native.country       42
# income                2
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# age               0.0
# workclass         0.0
# fnlwgt            0.0
# education         0.0
# education.num     0.0
# marital.status    0.0
# occupation        0.0
# relationship      0.0
# race              0.0
# sex               0.0
# capital.gain      0.0
# capital.loss      0.0
# hours.per.week    0.0
# native.country    0.0
# income            0.0
# dtype: float64

# %%
df['workclass'].unique()
# Out:
# <StringArray>
# [               '?',          'Private',        'State-gov',
#       'Federal-gov', 'Self-emp-not-inc',     'Self-emp-inc',
#         'Local-gov',      'Without-pay',     'Never-worked']
# Length: 9, dtype: str

# %%
df = pd.read_csv("adult.csv", na_values='?')

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
df['income'].unique()
# Out:
# <StringArray>
# ['<=50K', '>50K']
# Length: 2, dtype: str

# %%
#Seperating Features and targets
x=df.drop('income',axis=1)
y=df['income']

# %%
num_df=df.select_dtypes(include=['number'])

# %%
corr_matrix=num_df.corr()

# %%
corr_matrix
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education.num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital.gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital.loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours.per.week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours.per.week
# age                   0.068756
# fnlwgt               -0.018768
# education.num         0.148123
# capital.gain          0.078409
# capital.loss          0.054256
# hours.per.week        1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')

plt.show()

# %% [markdown]
# 2) WRAPPER METHOD

# %% [markdown]
# A) RFE

# %%
import pandas as pd

df=pd.read_csv('adult.csv')

x=df.drop('income',axis=1)
y=df['income']

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
x.head()
# Out:
#    age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 0   90   77053              9             0          4356              40
# 1   82  132870              9             0          4356              18
# 2   66  186061             10             0          4356              40
# 3   54  140359              4             0          3900              40
# 4   41  264663             10             0          3900              40
#
#    workclass_Federal-gov  workclass_Local-gov  workclass_Never-worked  \
# 0                  False                False                   False
# 1                  False                False                   False
# 2                  False                False                   False
# 3                  False                False                   False
# 4                  False                False                   False
#
#    workclass_Private  ...  native.country_Portugal  \
# ...

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

model=LogisticRegression(max_iter=1000)

rfe=RFE(estimator=model,n_features_to_select=10)

# %%
rfe.fit(x,y)
# Out:
# c:\Users\ASUS TUF\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\ASUS TUF\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# ...

# %%
selected_features=x.columns[rfe.support_]
selected_features
# Out:
# Index(['education_5th-6th', 'education_Doctorate', 'education_Prof-school',
#        'marital.status_Married-AF-spouse', 'marital.status_Married-civ-spouse',
#        'occupation_Priv-house-serv', 'relationship_Own-child',
#        'native.country_Columbia', 'native.country_Dominican-Republic',
#        'native.country_Mexico'],
#       dtype='str')

# %%
removed_features=x.columns[~rfe.support_]
removed_features
# Out:
# Index(['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss',
#        'hours.per.week', 'workclass_Federal-gov', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private', 'workclass_Self-emp-inc',
#        'workclass_Self-emp-not-inc', 'workclass_State-gov',
#        'workclass_Without-pay', 'education_11th', 'education_12th',
#        'education_1st-4th', 'education_7th-8th', 'education_9th',
#        'education_Assoc-acdm', 'education_Assoc-voc', 'education_Bachelors',
#        'education_HS-grad', 'education_Masters', 'education_Preschool',
#        'education_Some-college', 'marital.status_Married-spouse-absent',
#        'marital.status_Never-married', 'marital.status_Separated',
#        'marital.status_Widowed', 'occupation_Adm-clerical',
#        'occupation_Armed-Forces', 'occupation_Craft-repair',
#        'occupation_Exec-managerial', 'occupation_Farming-fishing',
#        'occupation_Handlers-cleaners', 'occupation_Machine-op-inspct',
# ...

# %%
ranking=pd.DataFrame({"Features":x.columns,
                      "Ranking":rfe.ranking_})

ranking.sort_values("Ranking")
# Out:
#                              Features  Ranking
# 27              education_Prof-school        1
# 29   marital.status_Married-AF-spouse        1
# 23                education_Doctorate        1
# 30  marital.status_Married-civ-spouse        1
# 17                  education_5th-6th        1
# ..                                ...      ...
# 4                        capital.loss       87
# 3                        capital.gain       88
# 82               native.country_Japan       89
# 79             native.country_Ireland       90
# 1                              fnlwgt       91
#
# [100 rows x 2 columns]

# %% [markdown]
# B) STEPWISE SELECTION

# %%
import pandas as pd

df=pd.read_csv('adult.csv',na_values='?')

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
import numpy as np
df.replace('?',np.nan,inplace=True)
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.dropna(inplace=True)

# %%
x=df.drop('income',axis=1)
y=df['income']

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
x_small=df.select_dtypes(include='number')

# %%
x=pd.get_dummies(x_small,drop_first=True)

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LogisticRegression

model=LogisticRegression(max_iter=1000)

sfs=SequentialFeatureSelector(estimator=model,n_features_to_select=5,direction='forward')

# %%
sfs.fit(x_small,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(max_iter=1000),
#                           n_features_to_select=5)

# %%
selected_features=x_small.columns[sfs.support_]
selected_features
# Out:
# Index(['age', 'fnlwgt', 'education.num', 'capital.loss', 'hours.per.week'], dtype='str')

# %%
removed_features=x_small.columns[~sfs.support_]
removed_features
# Out:
# Index(['capital.gain'], dtype='str')

# %%
ranking=pd.DataFrame({"Features":x_small.columns,
                      "Selected":sfs.get_support()})
ranking
# Out:
#          Features  Selected
# 0             age      True
# 1          fnlwgt      True
# 2   education.num      True
# 3    capital.gain     False
# 4    capital.loss      True
# 5  hours.per.week      True

# %% [markdown]
# 3) EMBEDDED METHOD

# %% [markdown]
# A) LASSO

# %%
import pandas as pd
df=pd.read_csv('adult.csv',na_values="?")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  str
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  str
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  str
#  6   occupation      30718 non-null  str
#  7   relationship    32561 non-null  str
#  8   race            32561 non-null  str
#  9   sex             32561 non-null  str
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  31978 non-null  str
#  14  income          32561 non-null  str
# dtypes: int64(6), str(9)
# memory usage: 3.7 MB

# %%
import numpy as np
df.replace('?',np.nan,inplace=True)
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df['income'].unique()
# Out:
# <StringArray>
# ['<=50K', '>50K']
# Length: 2, dtype: str

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# occupation        1843
# workclass         1836
# native.country     583
# fnlwgt               0
# education            0
# education.num        0
# age                  0
# marital.status       0
# relationship         0
# sex                  0
# race                 0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# income               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df['income']=df['income'].map({'<=50K':0,
                               '>50K':1})

# %%
df['income'].unique()
# Out:
# array([0, 1])

# %%
x_small=df.select_dtypes(include='number').drop('income',axis=1)

# %%
y=df['income']

# %%
df['income'].unique()
# Out:
# array([0, 1])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

x_scale=scaler.fit_transform(x_small)

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.01)

lasso.fit(x_scale,y)
# Out:
# Lasso(alpha=0.01)

# %%
coef=pd.DataFrame({'Features':x_small.columns,
                   "Coefficient":lasso.coef_})

# %%
coef.round(2)
# Out:
#          Features  Coefficient
# 0             age         0.08
# 1          fnlwgt         0.00
# 2   education.num         0.11
# 3    capital.gain         0.06
# 4    capital.loss         0.04
# 5  hours.per.week         0.06

# %%
selected_features=coef[coef['Coefficient']!=0]['Features']
selected_features
# Out:
# 0               age
# 2     education.num
# 3      capital.gain
# 4      capital.loss
# 5    hours.per.week
# Name: Features, dtype: str

# %%
removed_features=coef[coef['Coefficient']==0]['Features']
removed_features
# Out:
# 1    fnlwgt
# Name: Features, dtype: str

# %% [markdown]
# 2) RIDGE

# %%
import pandas as pd
df=pd.read_csv('adult.csv',na_values='?')

# %%
import numpy as np
df.replace('?',np.nan,inplace=True)
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df['income']=df['income'].map({'<=50K':0,
                               '>50K':1})

# %%
df['income'].unique()
# Out:
# array([0, 1])

# %%
x_small=df.select_dtypes(include='number').drop('income',axis=1)

# %%
y=df['income']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scale=scaler.fit_transform(x_small)

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=1)

# %%
ridge.fit(x_scale,y)
# Out:
# Ridge(alpha=1)

# %%
coef=pd.DataFrame({'Features':x_small.columns,
                   'Coefficients':ridge.coef_})
coef.round(2).sort_values('Coefficients')
# Out:
#          Features  Coefficients
# 1          fnlwgt          0.01
# 4    capital.loss          0.05
# 5  hours.per.week          0.06
# 3    capital.gain          0.07
# 0             age          0.09
# 2   education.num          0.12

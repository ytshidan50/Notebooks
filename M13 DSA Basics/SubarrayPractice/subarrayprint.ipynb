# %%
arr = [1,4,2,5,7,8,4,3,6,2,7,0,9]

for i in range(len(arr)):
    for j in range(i, len(arr)):
        print(arr[i:j+1])
# Out:
# [1]
# [1, 4]
# [1, 4, 2]
# [1, 4, 2, 5]
# [1, 4, 2, 5, 7]
# [1, 4, 2, 5, 7, 8]
# [1, 4, 2, 5, 7, 8, 4]
# [1, 4, 2, 5, 7, 8, 4, 3]
# [1, 4, 2, 5, 7, 8, 4, 3, 6]
# [1, 4, 2, 5, 7, 8, 4, 3, 6, 2]
# [1, 4, 2, 5, 7, 8, 4, 3, 6, 2, 7]
# [1, 4, 2, 5, 7, 8, 4, 3, 6, 2, 7, 0]
# [1, 4, 2, 5, 7, 8, 4, 3, 6, 2, 7, 0, 9]
# [4]
# [4, 2]
# [4, 2, 5]
# [4, 2, 5, 7]
# [4, 2, 5, 7, 8]
# [4, 2, 5, 7, 8, 4]
# [4, 2, 5, 7, 8, 4, 3]
# [4, 2, 5, 7, 8, 4, 3, 6]
# [4, 2, 5, 7, 8, 4, 3, 6, 2]
# [4, 2, 5, 7, 8, 4, 3, 6, 2, 7]
# [4, 2, 5, 7, 8, 4, 3, 6, 2, 7, 0]
# [4, 2, 5, 7, 8, 4, 3, 6, 2, 7, 0, 9]
# [2]
# [2, 5]
# [2, 5, 7]
# [2, 5, 7, 8]
# [2, 5, 7, 8, 4]
# [2, 5, 7, 8, 4, 3]
# [2, 5, 7, 8, 4, 3, 6]
# [2, 5, 7, 8, 4, 3, 6, 2]
# [2, 5, 7, 8, 4, 3, 6, 2, 7]
# [2, 5, 7, 8, 4, 3, 6, 2, 7, 0]
# [2, 5, 7, 8, 4, 3, 6, 2, 7, 0, 9]
# [5]
# [5, 7]
# [5, 7, 8]
# [5, 7, 8, 4]
# [5, 7, 8, 4, 3]
# [5, 7, 8, 4, 3, 6]
# [5, 7, 8, 4, 3, 6, 2]
# [5, 7, 8, 4, 3, 6, 2, 7]
# [5, 7, 8, 4, 3, 6, 2, 7, 0]
# ...
